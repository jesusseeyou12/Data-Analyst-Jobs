# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import io
import re
import numpy as np
from collections import Counter
import logging
import asyncio
from telegram import Update
from telegram.ext import Application, CommandHandler, ContextTypes
import nest_asyncio
nest_asyncio.apply()

# %%
logging.basicConfig(
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    level=logging.INFO
)
logger = logging.getLogger(__name__)

# %%
def load_data():
    try:
        df = pd.read_csv('DataAnalystJobs.csv')
        
        # Очистка и преобразование зарплат
        def clean_salary(salary):
            if isinstance(salary, str):
                numbers = re.findall(r'\d+', salary)
                if len(numbers) >= 2:
                    return (int(numbers[0]) + int(numbers[1])) / 2
            return np.nan
        
        df['Salary_Avg'] = df['Salary Estimate'].apply(clean_salary)
        df['City'] = df['Location'].str.split(',').str[0]
        
        # Извлечение навыков
        def extract_skills(text):
            skills = ['python', 'sql', 'r', 'tableau', 'excel', 'machine learning', 
                     'statistics', 'data visualization', 'power bi', 'hadoop', 
                     'spark', 'sas', 'matlab', 'pandas', 'numpy', 'scikit-learn']
            found_skills = []
            text = str(text).lower()
            for skill in skills:
                if skill in text:
                    found_skills.append(skill)
            return found_skills
        
        df['Skills'] = df['Job Description'].apply(extract_skills)
        all_skills = [skill for sublist in df['Skills'] for skill in sublist]
        skill_counts = Counter(all_skills)
        
        # Извлечение опыта
        def extract_experience(desc):
            if isinstance(desc, str):
                desc = desc.lower()
                if 'entry level' in desc or '0-2 years' in desc or '1-2 years' in desc:
                    return 'Entry (0-2 years)'
                elif 'junior' in desc or '2-4 years' in desc:
                    return 'Junior (2-4 years)'
                elif 'senior' in desc or '5+ years' in desc or '5-7 years' in desc:
                    return 'Senior (5+ years)'
                elif 'mid' in desc or '3-5 years' in desc:
                    return 'Mid (3-5 years)'
            return 'Not specified'
        
        df['Experience'] = df['Job Description'].apply(extract_experience)
        
        return df, skill_counts
    
    except Exception as e:
        logger.error(f"Ошибка при загрузке данных: {e}")
        return None, None

# %%
df, skill_counts = load_data()

# %%
def plot_skills():
    skills_df = pd.DataFrame.from_dict(skill_counts, orient='index').reset_index()
    skills_df.columns = ['Skill', 'Count']
    skills_df = skills_df.sort_values('Count', ascending=False).head(15)
    
    plt.figure(figsize=(10, 6))
    sns.barplot(x='Count', y='Skill', data=skills_df, palette='viridis')
    plt.title('Топ-15 самых востребованных навыков')
    buf = io.BytesIO()
    plt.savefig(buf, format='png', bbox_inches='tight')
    plt.close()
    buf.seek(0)
    return buf

def plot_city_salary():
    city_counts = df['City'].value_counts()
    top_cities = city_counts[city_counts >= 5].index
    city_salary = df[df['City'].isin(top_cities)].groupby('City')['Salary_Avg'].mean().sort_values(ascending=False).head(10)
    
    plt.figure(figsize=(10, 6))
    city_salary.plot(kind='bar', color='skyblue')
    plt.title('Средняя зарплата по городам (5+ вакансий)')
    plt.ylabel('Зарплата ($K)')
    plt.xticks(rotation=45)
    buf = io.BytesIO()
    plt.savefig(buf, format='png', bbox_inches='tight')
    plt.close()
    buf.seek(0)
    return buf

def plot_exp_salary():
    exp_salary = df[df['Experience'] != 'Not specified'].groupby('Experience')['Salary_Avg'].mean()
    exp_order = ['Entry (0-2 years)', 'Junior (2-4 years)', 'Mid (3-5 years)', 'Senior (5+ years)']
    exp_salary = exp_salary.reindex(exp_order)
    
    plt.figure(figsize=(10, 6))
    sns.barplot(x=exp_salary.index, y=exp_salary.values, palette='coolwarm')
    plt.title('Зарплаты по уровню опыта')
    plt.ylabel('Зарплата ($K)')
    plt.xticks(rotation=45)
    buf = io.BytesIO()
    plt.savefig(buf, format='png', bbox_inches='tight')
    plt.close()
    buf.seek(0)
    return buf

# %%
async def start(update: Update, context: ContextTypes.DEFAULT_TYPE):
    """Отправляет приветственное сообщение"""
    user = update.effective_user
    await update.message.reply_text(
        f"Привет {user.first_name}!\n"
        "Я бот для анализа вакансий Data Analyst.\n"
        "Доступные команды:\n"
        "/skills - Топ навыков\n"
        "/salary_by_city - Зарплаты по городам\n"
        "/salary_by_exp - Зарплаты по опыту\n"
        "/help - Помощь"
    )

async def help_command(update: Update, context: ContextTypes.DEFAULT_TYPE):
    """Отправляет справку"""
    await update.message.reply_text(
        "Доступные команды:\n"
        "/skills - Топ навыков\n"
        "/salary_by_city - Зарплаты по городам\n"
        "/salary_by_exp - Зарплаты по опыту\n"
        "/help - Эта справка"
    )

async def skills_stats(update: Update, context: ContextTypes.DEFAULT_TYPE):
    """Отправляет статистику по навыкам"""
    buf = plot_skills()
    await update.message.reply_photo(photo=buf, caption="Топ-15 самых востребованных навыков для Data Analyst")
    buf.close()

async def salary_by_city(update: Update, context: ContextTypes.DEFAULT_TYPE):
    """Отправляет статистику зарплат по городам"""
    buf = plot_city_salary()
    await update.message.reply_photo(photo=buf, caption="Средние зарплаты Data Analyst по городам США")
    buf.close()

async def salary_by_exp(update: Update, context: ContextTypes.DEFAULT_TYPE):
    """Отправляет статистику зарплат по опыту"""
    buf = plot_exp_salary()
    await update.message.reply_photo(photo=buf, caption="Зависимость зарплаты Data Analyst от опыта работы")
    buf.close()

async def error_handler(update: object, context: ContextTypes.DEFAULT_TYPE):
    """Логирует ошибки"""
    logger.error(f'Ошибка: {context.error}')

def main():
    """Запуск бота"""
    
    TOKEN = "7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8"
    
    
    application = Application.builder().token(TOKEN).build()

  
    application.add_handler(CommandHandler("start", start))
    application.add_handler(CommandHandler("help", help_command))
    application.add_handler(CommandHandler("skills", skills_stats))
    application.add_handler(CommandHandler("salary_by_city", salary_by_city))
    application.add_handler(CommandHandler("salary_by_exp", salary_by_exp))
    
    
    application.add_error_handler(error_handler)

    
    application.run_polling()

if __name__ == '__main__':
    main()
# Out:
# 2025-07-10 15:14:18,273 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getMe "HTTP/1.1 200 OK"
# 2025-07-10 15:14:18,294 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/deleteWebhook "HTTP/1.1 200 OK"
# 2025-07-10 15:14:18,300 - apscheduler.scheduler - INFO - Scheduler started
# 2025-07-10 15:14:18,302 - telegram.ext.Application - INFO - Application started
# 2025-07-10 15:14:27,852 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:14:28,407 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/sendPhoto "HTTP/1.1 200 OK"
# 2025-07-10 15:14:38,270 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:14:48,296 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:14:58,317 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:15:08,340 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:15:18,361 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:15:26,691 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:15:27,161 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/sendPhoto "HTTP/1.1 200 OK"
# 2025-07-10 15:15:34,065 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:15:44,084 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:15:44,794 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:15:44,907 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/sendMessage "HTTP/1.1 200 OK"
# 2025-07-10 15:15:49,008 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:15:49,393 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/sendPhoto "HTTP/1.1 200 OK"
# 2025-07-10 15:15:59,251 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:16:09,276 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:16:19,296 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:16:29,318 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:16:39,340 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:16:49,357 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:16:59,380 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:17:09,401 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:17:19,422 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:17:29,445 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:17:39,464 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:17:49,486 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:17:59,511 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:18:09,537 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:18:19,561 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:18:29,581 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:18:39,602 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:18:49,624 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:18:59,647 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:19:09,675 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:19:19,707 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:19:29,727 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:19:39,784 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:19:49,810 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:19:59,835 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:20:09,855 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:20:19,876 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:20:29,898 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:20:39,918 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:20:49,936 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:20:59,961 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:21:09,983 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:21:20,001 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:21:30,024 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:21:40,041 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:21:48,825 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:21:48,931 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/sendMessage "HTTP/1.1 200 OK"
# 2025-07-10 15:21:51,624 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:21:52,061 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/sendPhoto "HTTP/1.1 200 OK"
# 2025-07-10 15:22:01,940 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:22:11,960 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:22:21,988 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:22:32,010 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:22:42,029 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:22:45,272 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:22:45,748 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/sendPhoto "HTTP/1.1 200 OK"
# 2025-07-10 15:22:49,064 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:22:49,398 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/sendPhoto "HTTP/1.1 200 OK"
# 2025-07-10 15:22:59,344 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:23:09,368 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:23:19,390 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:23:29,411 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:23:39,430 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:23:49,452 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:23:59,475 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:24:09,496 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:24:19,517 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:24:29,540 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:24:39,561 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:24:49,579 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:24:59,600 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:25:09,625 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:25:19,649 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:25:29,670 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:25:39,692 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:25:49,722 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:25:59,743 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:26:09,766 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:26:19,790 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:26:29,813 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:26:39,833 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:26:49,854 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:26:59,872 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:27:09,890 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:27:19,914 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:27:29,936 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:27:39,959 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:27:49,984 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:28:00,004 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:28:05,139 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:28:05,270 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/sendMessage "HTTP/1.1 200 OK"
# 2025-07-10 15:28:10,881 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:28:11,227 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/sendPhoto "HTTP/1.1 200 OK"
# 2025-07-10 15:28:15,666 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:28:16,091 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/sendPhoto "HTTP/1.1 200 OK"
# 2025-07-10 15:28:21,045 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:28:21,540 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/sendPhoto "HTTP/1.1 200 OK"
# 2025-07-10 15:28:27,110 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:28:27,186 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/sendMessage "HTTP/1.1 200 OK"
# 2025-07-10 15:28:37,136 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:28:37,878 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:28:47,901 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:28:57,931 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:29:07,955 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:29:17,982 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:29:28,003 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:29:38,025 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:29:48,047 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:29:58,107 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:30:08,130 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:30:18,156 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:30:28,180 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:30:38,201 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:30:48,225 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:30:58,250 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:31:08,273 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:31:18,293 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:31:28,317 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:31:38,340 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:31:48,363 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:31:58,387 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:32:08,408 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:32:18,427 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:32:28,448 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:32:38,473 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:32:48,492 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:32:58,517 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:33:08,541 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
# 2025-07-10 15:33:18,567 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7762132323:AAH1rVzaY97aYpxm2cEMcc79SwicSCRm6U8/getUpdates "HTTP/1.1 200 OK"
